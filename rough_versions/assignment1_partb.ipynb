# %% [markdown]
# #### Assignment 2 - Python Basics: Operators & Mathematics - Part - B

# %% [markdown]
# ##### <i><u>Given references for Part - B </i></u>
#
# ##### **Python Operator Precedence** (Highest to Lowest)
# 1. Parantheses ()
# 2. Exponentiation **
# 3. Unary +,-,⁻
# 4. Multiplication *, Division /, Floor Division //, Modulo %
# 5. Addition +, Subtraction -
# 6. Bitwise Shifts <<, >>
# 7. Bitwise AND &
# 8. Bitwise XOR ^
# 9. Bitwise OR |
# 10. Comparisons <,<=,>,>=,!=,==
# 11. Logical NOT not
# 12. Logical AND and
# 13. Logical OR or
#
# ##### **Bitwise Operations Quick Reference**
# - & - AND: both bits must be 1
# - | - OR: at least one bit is 1
# - ^ - XOR: bits are different
# - ~ - NOT: flip all bits
# - << - Left Shift: multiply by 2ⁿ
# - '>>' - Right Shift: divide by 2ⁿ

# %% [markdown]
# $$ \small \underline{\textbf{Question - 1}}$$
# ```python
# (7 ^ 3) * (8 >> 2) + 9 % 4
# ```
# Just trying in latex

# %% [markdown]
# ##### Evaluating the given expression after breaking it down
#
# ##### Step 1: Break down the expression

# %% [markdown]
# ###### Evaluating (7 ^ 3) * (8 >> 2) + 9 % 4
#
# ###### Step 1: Break down the expression
# Expression: (7 ^ 3) * (8 >> 2) + 9 % 4
#
# ###### Part A: 7 ^ 3 (Bitwise XOR)
# | Number | Binary | Explanation |
# |--------|--------|-------------|
# |7       | 0111   | Binary of 7 |
# |3       | 0011   | Binary of 3 |
# |Result  | 0100   | XOR -> 1 if bits differ -> Decimal 4|

# %% [markdown]
# | Number | Binary | Explanation |
# |--------|--------|-------------|
# | 7      | 0111   | Original binary of 7 |
# | 3      | 0011   | Original binary of 3 |
# | Result | 0100   | XOR → 1 if bits differ → Decimal 4 |

# %% [markdown]
# Thinking of tabular format  (double space at the end gives a new linebreak)
# 7 ^ 3 →
# 0111
# 0011
# <u>0100</u> → Decimal 4

# %% [markdown]
# $ \rightarrow $ (arrow sign in latex)
#
# tabular structure in latex
# $$
# \begin{array}{|c|c|c|}
# \hline
# \text{Number} & \text{Binary} & \text{Explanation} \\
# \hline
# 7 & 0111 & \text{Original binary of 7} \\
# 3 & 0011 & \text{Original binary of 3} \\
# \text{Result} & 0100 & \text{XOR → Decimal 4} \\
# \hline
# \end{array}
# $$

# %% [markdown]
# ##### Manual Evaluation in LaTeX
#
# $$
# \begin{array}{|c|c|c|}
# \hline
# \text{Step} & \text{Operation} & \text{Result} \\
# \hline
# 1 & 7 \; ^ \; 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\
# \hline
# 0100 \; \rightarrow \; 4
# \end{array} \\
# \hline
# 2 & 8 \; >> \; 2 &
# \begin{array}{c}
# 1000 >> 2 = 0010 \\
# \rightarrow 2
# \end{array} \\
# \hline
# 3 & 9 \% 4 &
# \begin{array}{c}
# 9 \div 4 = 2 \; \text{remainder} \; 1 \\
# \rightarrow 1
# \end{array} \\
# \hline
# 4 & (7 ^ 3) \cdot (8 >> 2) + (9 \% 4) &
# (4 \cdot 2) + 1 = 9 \\
# \hline
# \end{array}
# $$

# %% [markdown]
# ##### Tabular format without LateX
#
# | Step | Operation | Result |
# |------|-----------|--------|
# | 1    | 7 ^ 3     | 0111 ^ 0011 = 0100 → 4 |
# | 2    | 8 >> 2    | 1000 >> 2 = 0010 → 2 |
# | 3    | 9 % 4     | 9 ÷ 4 = 2 remainder 1 → 1 |
# | 4    | Final     | (4 * 2) + 1 = 9 |

# %% [markdown]
# $$
# \begin{array}{|c|c|c|}
# \hline
# \text{Step} & \text{Operation} & \text{Result} \\
# \hline
# 1 & 7 \; ^ \; 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\
# \hline
# 0100 \; \rightarrow \; 4
# \end{array} \\
# \hline
# 2 & 8 \; >> \; 2 &
# 1000 >> 2 = 0010 \; \rightarrow \; 2 \\
# \hline
# 3 & 9 \% 4 &
# 9 \div 4 = 2 \; \text{remainder} \; 1 \; \rightarrow \; 1 \\
# \hline
# 4 & \text{Final} & (4 \cdot 2) + 1 = 9 \\
# \hline
# \end{array}
# $$
# >Note: The XOR operator (^) seems to be missing here. Its name seemed to be \textasciicircum and is known as Caret/Circumflex symbol. Also '>>' '<<' seem to be  \gg and \ll respectively for shift operations.

# %% [markdown]
# $$
# \begin{array}{|c|c|c|}
# \hline
# \text{Step} & \text{Operation} & \text{Result} \\
# \hline
# 1 & 7 \; \textasciicircum \; 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\
# \hline
# 0100 \; \rightarrow \; 4
# \end{array} \\
# \hline
# 2 & 8 \; \gg \; 2 &
# 1000 \gg 2 = 0010 \; \rightarrow \; 2 \\
# \hline
# 3 & 9 \,\%\, 4 &
# 9 \div 4 = 2 \; \text{remainder} \; 1 \; \rightarrow \; 1 \\
# \hline
# 4 & \text{Final} & (4 \cdot 2) + 1 = 9 \\
# \hline
# \end{array}
# $$

# %% [markdown]
# # Tabular Documentation of Expression Evaluation
#
# We are solving:
#
# \[
# ((15^{2} \% 7 + 48 \gg 2) \oplus (19 \& 13 | 6)) \cdot (7 \ll 3 \div 5)
# + ((42 \% 5 \cdot 3^{3} \div 4) > (18 \gg 1))
# \;\land\; \neg((9 | 4) \oplus (12 \& 7) < (3^{2} + 5))
# \;\lor\; (27 \div 4 \% 3 == 2)
# \]
#
# ---
#
# ## Step-by-Step Evaluation Table
#
# | Block | Expression | Simplification | Result |
# |-------|------------|----------------|--------|
# | A (left) | \(15^2 \% 7\) | \(225 \% 7\) | 1 |
# | A (left) | \(48 \gg 2\) | \(48 / 2^2\) | 12 |
# | A (left sum) | \(1 + 12\) |  | 13 |
# | A (right) | \(19 \& 13\) | binary AND → 1 | 1 |
# | A (right) | \(1 | 6\) | OR → 7 | 7 |
# | A (xor) | \(13 \oplus 7\) | XOR → 10 | 10 |
# | A (shift) | \(7 \ll 3\) | 56 | 56 |
# | A (div) | \(56 // 5\) | 11 | 11 |
# | A (final) | \(10 \cdot 11\) |  | **110** |
# | B | \(42 \% 5\) | 2 | 2 |
# | B | \(3^3\) | 27 | 27 |
# | B | \(2 \cdot 27\) | 54 | 54 |
# | B | \(54 // 4\) | 13 | 13 |
# | B | \(18 \gg 1\) | 9 | 9 |
# | B (compare) | \(13 > 9\) | True | **1** |
# | C | \(9 | 4\) | 13 | 13 |
# | C | \(12 \& 7\) | 4 | 4 |
# | C | \(13 \oplus 4\) | 9 | 9 |
# | C | \(3^2 + 5\) | 14 | 14 |
# | C (compare) | \(9 < 14\) | True | 1 |
# | C (negation) | \(\neg 1\) | False | **0** |
# | D | \(27 // 4\) | 6 | 6 |
# | D | \(6 \% 3\) | 0 | 0 |
# | D (compare) | \(0 == 2\) | False | **0** |
#
# ---
#
# ## Final Combination
#
# | Step | Operation | Result |
# |------|-----------|--------|
# | A + B | \(110 + 1\) | 111 |
# | (A+B) and C | \(111 \land 0\) | 0 |
# | Previous or D | \(0 \lor 0\) | 0 |
#
# ---
#
# ## ✅ Final Answer
# \[
# \boxed{0}
# \]

# %% [markdown]
# $$ \small \underline{\textbf{Question - 1}}$$
# ```python
# (7 ^ 3) * (8 >> 2) + 9 % 4
# ```

# %% [markdown]
# ##### Evaluating the given expression
# ##### Step 1: Breaking down the expression

# %% [markdown]
# Expression: (7 ^ 3) * (8 >> 2) + 9 % 4
#
# ###### Part A: 7 ^ 3 (Bitwise XOR)
# | Number | Binary | Explanation |
# |--------|--------|-------------|
# |7       | 0111   | Binary of 7 |
# |3       | 0011   | Binary of 3 |
# |Result  | 0100   | XOR -> 1 if bits differ -> Decimal 4|

# %% [markdown]
# $$
# $$

# %% [markdown]
# $a^2 + b^2 = c^2$

# %% [markdown]
# ### Example: Right Shift (48 >> 2)
#
# | Decimal | Binary    | Operation | Result Binary | Result Decimal |
# |---------|-----------|-----------|---------------|----------------|
# | 48      | 110000    | >> 2      | 001100        | 12             |
#
# $$
# 48 \gg 2 = \frac{48}{2^2} = 12
# $$
#
# $$
# 7 \ll 3 = 7 \times 2^3 = 56
# $$

# %%
# Left Shift Example:

# 7 = 00000111
# 7 << 3 = 00111000 = 56 (shifting digit by 3 towards left and filling 0s at end)

# Another method:
# 7 << 3 = 7 * 2^3 = 7 * 8 = 56 (left shift -> multiply by 2^n)

# Right Shift Example:

# 48 >> 2 = 110000 
# = 001100  (shifting digit by 2 towards right and dumping values at end)
# = 12 

# Another Method:
# 48 >> 2 = 48/(2^n) = 48/4 = 12

# %% [markdown]
# ## Bitwise Shift Examples
#
# ### Right Shift
# $$
# 48 \gg 2 = \frac{48}{2^2} = 12
# $$
#
# | Decimal | Binary    | Operation | Result Binary | Result Decimal |
# |---------|-----------|-----------|---------------|----------------|
# | 48      | 110000    | >> 2      | 001100        | 12             |
#
# **Result: 48 >> 2 = 12**
#
# ---
#
# ### Left Shift
# $$
# 7 \ll 3 = 7 \times 2^3 = 56
# $$
#
# ```text
# 7        = 00000111
# 7 << 3   = 00111000 = 56

# %% [markdown]
# ### Example: Operations in Expression
#
# | Operation | Decimal A | Binary A   | Decimal B | Binary B   | Result Binary | Result Decimal | Notes |
# |-----------|-----------|------------|-----------|------------|---------------|----------------|-------|
# | AND (&)   | 19        | 10011      | 13        | 01101      | 00001         | 1              | Common bits only |
# | OR (|)    | 1         | 00001      | 6         | 00110      | 00111         | 7              | Either bit set |
# | XOR (^)   | 13        | 01101      | 7         | 00111      | 01010         | 10             | Bits differ |
# | Left Shift (<<) | 7   | 00000111   | Shift 3   | ---        | 00111000      | 56             | Multiply by \(2^3\) |
# | Right Shift (>>) | 48 | 110000     | Shift 2   | ---        | 001100        | 12             | Divide by \(2^2\) |

# %% [markdown]
# # Expression Evaluation Walkthrough
#
# We will evaluate the following expression step by step:
#
# $$
# ((15^{2} \% 7 + 48 \gg 2) \; \oplus \; (19 \& 13 \;|\; 6)) \cdot (7 \ll 3 \; // \; 5)
# + ((42 \% 5 \cdot 3^{3} // 4) > (18 \gg 1))
# \;\text{and not}\; ((9 | 4) \oplus (12 \& 7) < (3^{2} + 5))
# \;\text{or}\; (27 // 4 \% 3 == 2)
# $$
#
# ---
#
# ## Operations Table (Bitwise + Arithmetic)
#
# | Operation        | Decimal A | Binary A   | Decimal B | Binary B   | Result Binary | Result Decimal | Notes |
# |------------------|-----------|------------|-----------|------------|---------------|----------------|-------|
# | Power (**)       | 15        | ---        | 2         | ---        | ---           | 225            | Exponentiation |
# | Modulo (%)       | 225       | ---        | 7         | ---        | ---           | 1              | Remainder after division |
# | Right Shift (>>) | 48        | 110000     | Shift 2   | ---        | 001100        | 12             | Divide by \(2^2\) |
# | Addition (+)     | 1         | ---        | 12        | ---        | ---           | 13             | First bracket result |
# | AND (&)          | 19        | 10011      | 13        | 01101      | 00001         | 1              | Common bits only |
# | OR (|)           | 1         | 00001      | 6         | 00110      | 00111         | 7              | Either bit set |
# | XOR (^)          | 13        | 01101      | 7         | 00111      | 01010         | 10             | Bits differ |
# | Left Shift (<<)  | 7         | 00000111   | Shift 3   | ---        | 00111000      | 56             | Multiply by \(2^3\) |
# | Floor Division (//) | 56     | ---        | 5         | ---        | ---           | 11             | Integer division |
# | Multiplication (*) | 10      | ---        | 11        | ---        | ---           | 110            | First big product |
# | Modulo (%)       | 42        | ---        | 5         | ---        | ---           | 2              | Used in `(42 % 5)` |
# | Power (**)       | 3         | ---        | 3         | ---        | ---           | 27             | Exponentiation |
# | Multiplication (*) | 2       | ---        | 27        | ---        | ---           | 54             | Standard multiplication |
# | Floor Division (//) | 54     | ---        | 4         | ---        | ---           | 13             | Integer division |
# | Right Shift (>>) | 18        | 10010      | Shift 1   | ---        | 01001         | 9              | Used in `(18 >> 1)` |
# | Comparison (>)   | 13        | ---        | 9         | ---        | ---           | True (1)       | 13 > 9 |
# | Addition (+)     | 110       | ---        | 1         | ---        | ---           | 111            | Added comparison |
# | OR (|)           | 9         | 01001      | 4         | 00100      | 01101         | 13             | Used in `(9 | 4)` |
# | AND (&)          | 12        | 01100      | 7         | 00111      | 00100         | 4              | Used in `(12 & 7)` |
# | XOR (^)          | 13        | 01101      | 4         | 00100      | 01001         | 9              | Result of `(9 | 4) ^ (12 & 7)` |
# | Power (**)       | 3         | ---        | 2         | ---        | ---           | 9              | Used in `(3**2)` |
# | Addition (+)     | 9         | ---        | 5         | ---        | ---           | 14             | Used in `(3**2 + 5)` |
# | Comparison (<)   | 9         | ---        | 14        | ---        | ---           | True           | 9 < 14 |
# | NOT              | True      | ---        | ---       | ---        | ---           | False          | Negation |
# | Logical AND      | 111       | ---        | False     | ---        | ---           | 0              | 111 and False |
# | Floor Division (//) | 27     | ---        | 4         | ---        | ---           | 6              | Used in `(27 // 4)` |
# | Modulo (%)       | 6         | ---        | 3         | ---        | ---           | 0              | Used in `(27 // 4 % 3)` |
# | Comparison (==)  | 0         | ---        | 2         | ---        | ---           | False          | 0 == 2 |
# | Logical OR       | 0         | ---        | False     | ---        | ---           | 0              | Final OR |
#
# ---
#
# ## Final Combination Trace
#
# - First big bracket: \(13 \oplus 7 = 10\)
# - Multiply: \(10 \cdot 11 = 110\)
# - Add comparison: \(110 + 1 = 111\)
# - Logical AND NOT: \(111 \text{ and False} = 0\)
# - Final OR: \(0 \text{ or False} = 0\)
#
# ---
#
# # ✅ Final Answer
# $$
# \boxed{0}
# $$

# %% [markdown]
# # Tabular Documentation of Expression Evaluation
#
# We are solving:
#
# $$
# ((15^{2} \% 7 + 48 \gg 2) \oplus (19 \& 13 | 6)) \cdot (7 \ll 3 // 5)
# + ((42 \% 5 \cdot 3^{3} // 4) > (18 \gg 1))
# \;\land\; \neg((9 | 4) \oplus (12 \& 7) < (3^{2} + 5))
# \;\lor\; (27 // 4 \% 3 == 2)
# $$
#
# ---
#
# ## Step-by-Step Evaluation Table
#
# | Block | Expression | Simplification | Result |
# |-------|------------|----------------|--------|
# | A (left) | \(15^2 \% 7\) | \(225 \% 7\) | 1 |
# | A (left) | \(48 \gg 2\) | \(48 / 2^2\) | 12 |
# | A (left sum) | \(1 + 12\) |  | 13 |
# | A (right) | \(19 \& 13\) | binary AND → 1 | 1 |
# | A (right) | \(1 | 6\) | OR → 7 | 7 |
# | A (xor) | \(13 \oplus 7\) | XOR → 10 | 10 |
# | A (shift) | \(7 \ll 3\) | 56 | 56 |
# | A (div) | \(56 // 5\) | 11 | 11 |
# | A (final) | \(10 \cdot 11\) |  | **110** |
# | B | \(42 \% 5\) | 2 | 2 |
# | B | \(3^3\) | 27 | 27 |
# | B | \(2 \cdot 27\) | 54 | 54 |
# | B | \(54 // 4\) | 13 | 13 |
# | B | \(18 \gg 1\) | 9 | 9 |
# | B (compare) | \(13 > 9\) | True | **1** |
# | C | \(9 | 4\) | 13 | 13 |
# | C | \(12 \& 7\) | 4 | 4 |
# | C | \(13 \oplus 4\) | 9 | 9 |
# | C | \(3^2 + 5\) | 14 | 14 |
# | C (compare) | \(9 < 14\) | True | 1 |
# | C (negation) | \(\neg 1\) | False | **0** |
# | D | \(27 // 4\) | 6 | 6 |
# | D | \(6 \% 3\) | 0 | 0 |
# | D (compare) | \(0 == 2\) | False | **0** |
#
# ---
#
# ## Bitwise Operation Details
#
# | Operation | Decimal A | Binary A   | Decimal B | Binary B   | Result Binary | Result Decimal | Notes |
# |-----------|-----------|------------|-----------|------------|---------------|----------------|-------|
# | AND (&)   | 19        | 10011      | 13        | 01101      | 00001         | 1              | Common bits only |
# | OR (|)    | 1         | 00001      | 6         | 00110      | 00111         | 7              | Either bit set |
# | XOR (^)   | 13        | 01101      | 7         | 00111      | 01010         | 10             | Bits differ |
# | OR (|)    | 9         | 01001      | 4         | 00100      | 01101         | 13             | Used in `(9 | 4)` |
# | AND (&)   | 12        | 01100      | 7         | 00111      | 00100         | 4              | Used in `(12 & 7)` |
# | XOR (^)   | 13        | 01101      | 4         | 00100      | 01001         | 9              | Result of `(9 | 4) ^ (12 & 7)` |
# | Left Shift (<<) | 7   | 00000111   | Shift 3   | ---        | 00111000      | 56             | Multiply by \(2^3\) |
# | Right Shift (>>) | 48 | 110000     | Shift 2   | ---        | 001100        | 12             | Divide by \(2^2\) |
# | Right Shift (>>) | 18 | 10010      | Shift 1   | ---        | 01001         | 9              | Used in `(18 >> 1)` |
#
# ---
#
# ## Final Combination
#
# | Step | Operation | Result |
# |------|-----------|--------|
# | A + B | \(110 + 1\) | 111 |
# | (A+B) and C | \(111 \land 0\) | 0 |
# | Previous or D | \(0 \lor 0\) | 0 |
#
# ---
#
# # ✅ Final Answer
# $$
# \boxed{0}
# $$

# %% [markdown]
# # Tabular Documentation of Expression Evaluation
#
# We are solving:
#
# $$
# ((15^{2} \% 7 + 48 \gg 2) \oplus (19 \& 13 | 6)) \cdot (7 \ll 3 // 5)
# + ((42 \% 5 \cdot 3^{3} // 4) > (18 \gg 1))
# \;\land\; \neg((9 | 4) \oplus (12 \& 7) < (3^{2} + 5))
# \;\lor\; (27 // 4 \% 3 == 2)
# $$
#
# ---
#
# ## Step-by-Step Evaluation Table
#
# | Block | Expression | Simplification | Result |
# |-------|------------|----------------|--------|
# | A (left) | $$15^2 \% 7$$ | $$225 \% 7$$ | 1 |
# | A (left) | $$48 \gg 2$$ | $$48 / 2^2$$ | 12 |
# | A (left sum) | $$1 + 12$$ |  | 13 |
# | A (right) | $$19 \& 13$$ | binary AND → 1 | 1 |
# | A (right) | $$1 | 6$$ | OR → 7 | 7 |
# | A (xor) | $$13 \oplus 7$$ | XOR → 10 | 10 |
# | A (shift) | $$7 \ll 3$$ | 56 | 56 |
# | A (div) | $$56 // 5$$ | 11 | 11 |
# | A (final) | $$10 \cdot 11$$ |  | **110** |
# | B | $$42 \% 5$$ | 2 | 2 |
# | B | $$3^3$$ | 27 | 27 |
# | B | $$2 \cdot 27$$ | 54 | 54 |
# | B | $$54 // 4$$ | 13 | 13 |
# | B | $$18 \gg 1$$ | 9 | 9 |
# | B (compare) | $$13 > 9$$ | True | **1** |
# | C | $$9 | 4$$ | 13 | 13 |
# | C | $$12 \& 7$$ | 4 | 4 |
# | C | $$13 \oplus 4$$ | 9 | 9 |
# | C | $$3^2 + 5$$ | 14 | 14 |
# | C (compare) | $$9 < 14$$ | True | 1 |
# | C (negation) | $$\neg 1$$ | False | **0** |
# | D | $$27 // 4$$ | 6 | 6 |
# | D | $$6 \% 3$$ | 0 | 0 |
# | D (compare) | $$0 == 2$$ | False | **0** |
#
# ---
#
# ## Bitwise Operation Details
#
# | Operation | Decimal A | Binary A   | Decimal B | Binary B   | Result Binary | Result Decimal | Notes |
# |-----------|-----------|------------|-----------|------------|---------------|----------------|-------|
# | AND (&)   | 19        | 10011      | 13        | 01101      | 00001         | 1              | Common bits only |
# | OR (|)    | 1         | 00001      | 6         | 00110      | 00111         | 7              | Either bit set |
# | XOR (^)   | 13        | 01101      | 7         | 00111      | 01010         | 10             | Bits differ |
# | OR (|)    | 9         | 01001      | 4         | 00100      | 01101         | 13             | Used in $$9 | 4$$ |
# | AND (&)   | 12        | 01100      | 7         | 00111      | 00100         | 4              | Used in $$12 \& 7$$ |
# | XOR (^)   | 13        | 01101      | 4         | 00100      | 01001         | 9              | Result of $$(9 | 4) \oplus (12 \& 7)$$ |
# | Left Shift (<<) | 7   | 00000111   | Shift 3   | ---        | 00111000      | 56             | Multiply by $$2^3$$ |
# | Right Shift (>>) | 48 | 110000     | Shift 2   | ---        | 001100        | 12             | Divide by $$2^2$$ |
# | Right Shift (>>) | 18 | 10010      | Shift 1   | ---        | 01001         | 9              | Used in $$(18 \gg 1)$$ |
#
# ---
#
# ## Final Combination
#
# | Step | Operation | Result |
# |------|-----------|--------|
# | A + B | $$110 + 1$$ | 111 |
# | (A+B) and C | $$111 \land 0$$ | 0 |
# | Previous or D | $$0 \lor 0$$ | 0 |
#
# ---
#
# # ✅ Final Answer
# $$
# \boxed{0}
# $$

# %% [markdown]
# ###### Question - 1
# ```python
# (7 ^ 3) * (8 >> 2) + 9 % 4
# ```

# %% [markdown]
# Here, first step = break down the expression into blocks
# Block A = (7 ^ 3)
# |Decimal|Binary|Operation|
# |-------|------|---------|
# |7      | 0111 |  XOR(^) |
# |3      | 0011 |         |
# |Result (XOR) (^)| 0100 = 4|
#
# Block B = (8 >> 2)
# |Decimal|Binary| Operation |
# |-------|------|-----------|
# |8      | 1000 | Right Shift 2  |
# |Result (Right Shift 2) | 0010 = 2|
#
# Block C = 9 % 4 = 1
#
# Expression (simplified) = A * B + C
#                         = 4 * 2 + 1
#                         = 8 + 1
#                         = 9

# %% [markdown]
# ###### Latex Table
# $$
# \begin{array}{lcc}
# Name & Age & City\\
# \hline
# Ram & 25 & Kathmandu
# Shyam
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|}
# \hline
# Column 1 & Column 2 & Column 3 & Column 4 \\
# \hline
# Row 1    & Value    & Value    & Value    \\
# Row 2    & Value    & Value    & Value    \\
# \hline
# \end{array}
# $$

# %% [markdown]
# ##### Latex Table Version
# Step 1 = Breaking down the expression into blocks and operating on these terms in tabular form below
# $$
# \small \begin{array}{|l|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# XOR \,(\textasciicircum) & 7 & 3 &
# \begin{array}{l}
# 0111 \\
# 0011 \\ \hline
# 0100 \;\Rightarrow \; 4
# \end{array} \\
# \hline
# Right Shift \, (>>) & 8 & 2 &
# \begin{array}{l}
# 1000 \\
# \gg 2 \\
# \hline
# 0010 \; \Rightarrow \; 2 \\
# \end{array} \\
# \hline
# Modulo \, (\%) & 9 & 4 &
# \begin{array}{c}
# \tiny 9 \div 4 = 2 \; \tiny \text{remainder} \; 1 \\ \hline
# \tiny 9 \,\%\, 4 \; \Rightarrow 1
# \end{array} \\
# \hline
# \end{array}
# $$
#
# Step 2 = Block A * Block B + Block C
#        = 4 * 2 + 1
#        = 9

# %% [markdown]
# $ \boxed{\text{Block A} = 4} \quad
# \boxed{\text{Block B} = 2} \quad
# \boxed{\text{Block C} = 1} $
#
# $$
# \boxed{\text{Expression} = \text{Block A} \cdot \text{Block B} + \text{Block C} = 9}
# $$

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# AND (\&) & 19 & 13 &
# $\begin{array}{c}
# 10011 \\
# 01101 \\ \hline
# 00001 \; \Rightarrow \; 1
# \end{array}$ \\
# \hline
# OR (|) & 1 & 6 &
# $\begin{array}{c}
# 00001 \\
# 00110 \\ \hline
# 00111 \; \Rightarrow \; 7
# \end{array}$ \\
# \hline
# XOR (^) & 13 & 7 &
# $\begin{array}{c}
# 01101 \\
# 00111 \\ \hline
# 01010 \; \Rightarrow \; 10
# \end{array}$ \\
# \hline
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{|c|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# AND (\&) & 19 & 13 &
# $\begin{array}{c}
# 10011 \\
# 01101 \\ \hline
# 00001 \;\Rightarrow\; 1
# \end{array}$ \\
# \hline
# OR (|) & 1 & 6 &
# $\begin{array}{c}
# 00001 \\
# 00110 \\ \hline
# 00111 \;\Rightarrow\; 7
# \end{array}$ \\
# \hline
# XOR (^) & 13 & 7 &
# $\begin{array}{c}
# 01101 \\
# 00111 \\ \hline
# 01010 \;\Rightarrow\; 4
# \end{array}$ \\
# \hline
# \end{array}
# $$

# %% [markdown]
# $\begin{array}{r}
# 10011 \\
# 01101 \\ \hline
# 00001 \;\Rightarrow\; 1
# \end{array}$

# %% [markdown]
# $$
# \begin{array}{|l|c|c|c|}
# \hline
# Operation & Decimal A & Shift Amount & Result \\
# \hline
# Right Shift (>>) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \gg 2 \\ \hline
# 0010 \;\Rightarrow\; 2
# \end{array} \\
# \hline
# Left Shift (<<) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \ll 2 \\ \hline
# 100000 \;\Rightarrow\; 32
# \end{array} \\
# \hline
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{|l|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# XOR (\textasciicircum) & 7 & 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\ \hline
# 0100 \;\Rightarrow\; 4
# \end{array} \\
# \hline
# Right Shift (>>) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \gg 2 \\ \hline
# 0010 \;\Rightarrow\; 2
# \end{array} \\
# \hline
# Left Shift (<<) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \ll 2 \\ \hline
# 100000 \;\Rightarrow\; 32
# \end{array} \\
# \hline
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{|l|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# XOR (\textasciicircum) & 7 & 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\ \hline
# 0100 \;\Rightarrow\; 4
# \end{array} \\
# \hline
# Right Shift (>>) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \gg 2 \\ \hline
# 0010 \;\Rightarrow\; 2
# \end{array} \\
# \hline
# Modulo (\%) & 19 & 7 &
# \begin{array}{c}
# 19 \div 7 = 2 \text{ remainder } 5 \\ \hline
# 19 \% 7 \;\Rightarrow\; 5
# \end{array} \\
# \hline
# \end{array}
# $$

# %% [markdown]
# $$
# \begin{array}{|l|c|c|c|}
# \hline
# Operation & Decimal A & Decimal B & Result \\
# \hline
# XOR (\textasciicircum) & 7 & 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\ \hline
# 0100 \;\Rightarrow\; 4
# \end{array} \\
# \hline
# Right Shift (>>) & 8 & 2 &
# \begin{array}{c}
# 1000 \\
# \gg 2 \\ \hline
# 0010 \;\Rightarrow\; 2
# \end{array} \\
# \hline
# Modulo (\%) & 19 & 7 &
# \begin{array}{c}
# 19 \div 7 = 2 \text{ remainder } 5 \\ \hline
# 19 \% 7 \;\Rightarrow\; 5
# \end{array} \\
# \hline
# \end{array}
# $$

# %% [markdown]
# ###### Question - 1
#
# 7 ^ 3 = 0111 ^ 0011
#       = 0100
#       = 4
# 8 >> 2 = 1000 >> 2
#        = 0010
#        = 2
# 9 % 4 = 1
#
# final expression = 4 * 2 + 1
#                  = 9

# %%
# Example verification
result = (7 ^ 3) * (8 >> 2) + 9 % 4
print ( f" Result : { result } " )
print ( f" Binary : { bin ( result ) } " )
# Out:
#  Result : 9
#  Binary : 0b1001

# %% [markdown]
# ###### Question - 2
#
# 14 >> 1 = 7
# 9 % 5 = 4
# 6 ^ 2 = 110 (6)
#       = 010 (2)
#       = 100
#       = 4
# final expression = 7 + 4 * 4
#                  = 7 + 16
#                  = 23

# %%
(14 >> 1) + (9 % 5) * (6 ^ 2)
# Out:
# 23

# %% [markdown]
# ###### Question - 3
# 5**3 = 125
# 125 // 4 = 31
# 31 % 7 = 3
# 3 << 2 = 0011 << 2 = 1100 = 12
#
# 18 >> 2 = 10010 >> 2 = 00100 = 4
# 6 % 5 = 1
# 9 ^ 1 = 01001 ^ 00001 = 01000 = 8
# 4*8 = 32
#
# final expression = 12 + 32 = 44

# %%
(5**3 // 4 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)
# Out:
# 44

# %% [markdown]
# ###### Question - 4
# 3 ** 2 = 9
# 27 % 5 = 2
# 9 * 2 = 18
# 18 // 4 = 4
#
# 48 >> 3 = 110000 >> 3 = 000110 = 6
# 9 << 1 = 01001 << 1 = 10010 = 18
# 14 & 18 = 01110 & 10010
#         = 10010 (bringing 10010 below for simpler calculation)
#         = 00010
#         = 2
# final expression = 4 ^ 6 + 2
#                  = 4 ^ 8
#                  = 0100 ^ 1000
#                  = 1000 (bringing 1000 down for simpler calc)
#                  = 1100
#                  = 12

# %%
(27 % 5 * 3**2 // 4) ^ (48 >> 3) + (14 & 9 << 1)
# Out:
# 12

# %% [markdown]
# ##### Question - 5
#
# 19 | 6 = 10011 | 00110
#        = 10011 (bringing the latter part down for simpler calculation)
#        = 00110
#        = 10111
#        = 23
# 28 & 14 = 11100 & 01110
#         = 01110
#         = 01100
#         = 12
# 3 << 2 = 0011 << 2 = 1100 = 12
# 5 ** 2 = 25
# 25 // 3 = 8
#
# 23 ^ 12 = 10111 ^ 01100
#         = 01100
#         = 11011
#         = 27
#
# final expression = (23 ^ 12) * 12 % 8
#                  = 27 * 12 % 8
#                  = 324 % 8
#                  = 4

# %%
((19 | 6) ^ (28 & 14) ) * (3 << 2) % (5**2 // 3)
# Out:
# 4

# %% [markdown]
# ##### Question - 6
#
# 45 & 27 = 101101 & 011011
#         = 011011
#         = 001001
#         = 9
# 9 << 2 = 1001 << 2 = 100100 = 36
#
# 2 ** 3 = 8
# 9 % 4 = 1
# 1 + 8 = 9
#
# 5 << 1 = 0101 << 1 = 1010 = 10
# 16 ^ 10 = 10000 ^ 01010
#         = 01010
#         = 11010
#         = 26
#
# final expression = 36 // 9 + 26
#                  = 4 + 26
#                  = 30

# %%
((45 & 27) << 2) // (9 % 4 + (2**3)) + (16 ^ (5 << 1))
# Out:
# 30

# %% [markdown]
# ##### Question - 7
# 15**2 = 225
# 225 % 7 = 1
# 1 + 48 = 49
# 49 >> 2 = 110001 >> 2 = 001100 = 12
#
# 19 & 13 = 10011 & 01101
#         = 01101
#         = 00001 = 1
# 1 | 6 = 001 | 110 = 111 = 7
#
# 3 // 5 = 0
# 7 << 0 = 7
#
# 3**3 = 27
# 42 % 5 = 2
# 2 * 27 = 54
# 54 // 4 = 13
#
# 18 >> 1 = 9
#
# 9 | 4 = 1001 | 0100 = 1101 = 13
# 12 & 7 = 1100 & 0111 = 0100 = 4
# 13 ^ 4 = 1101 ^ 0100 = 1001 = 9
#
# 3**2 = 9
# 9 + 5 = 14
#
# 27 // 4 = 6
# 6 % 3 = 0
# 0 == 2 = False (0)
#
# 12 ^ 62 = 001100 ^ 111110
#         = 111110
#         = 110010 = 50
#
# final expression = 12 ^ 7 * 7 + 13 > 9 and not (9 < 14) or (0 == 2)
#                  = 12 ^ 49 + 13 > 9 and not (true) or (false)
#                  = 12 ^ 62 > 9 and not true
#                  = 50 > 9 and false
#                  = true and false
#                  = false

# %%
((15**2 % 7 + 48 >> 2) ^ (19 & 13 | 6) ) * (7 << 3 // 5) + ((42 % 5 * 3**3 // 4) > 
(18 >> 1)) and not ((9 | 4) ^ (12 & 7) < (3**2 + 5)) or (27 // 4 % 3 == 2)
# Out:
# False

# %% [markdown]
# ##### Question - 8
# 63 & 45 = 111111 & 101101
#         = 101101
#         = 101101
#         = 45
# 45 << 1 = 101101 << 1 = 1011010 = 90
# 72 >> 3 = 9
# 90 | 9 = 1011010 | 0001001 = 1011011 = 91
#
# 2**4 = 16
# 11 % 3 = 2
# 2 * 16 = 32
# 6 + 1 = 7
# 32 // 7 = 4
#
# 8 | 3 = 1000 | 0011 = 1011 = 11
# 11 ^ 5 = 1011 ^ 0101
#        = 0101
#        = 1110
#        = 14
# 16 >> 2 = 16/(2^2) = 4
# 14 * 4 = 56
# 56 % 7 = 0
#
# 25 % 6 = 1
# 1 << 2 = 4
#
# 91 ^ 4 = 1011011 ^ 0000100
#        = 0000100
#        = 1011111
#        = 95
#
# final expression = 91 ^ 4 + 0 - 4
#                  = 95 - 4
#                  = 91

# %%
((63 & 45) << 1 | (72 >> 3) ) ^ ((11 % 3 * 2**4) // (6 + 1)) + (((8 | 3) 
^ 5) * (16 >> 2) % 7) - ((25 % 6) << 2)
# Out:
# 91

# %% [markdown]
# ##### Question - 9
#
# 128 >> 3 = 128/(2^3) = 128/8 = 16
# 45 | 18 = 101101 | 010010 = 11111 = 63
# 16 & 63 = 010000 & 111111 = 010000 = 16
#
# 7**2 = 49
# 49 % 10 = 9
# 16 ^ 9 = 10000 ^ 01001
#        = 01001
#        = 11001
#        = 25
#
# 36 // 5 = 7
# 7 << 1 = 7 * 2^1 = 14
#
# 2 ** 3 = 8
# 91 % 7 = 0
# 0 * 8 = 0
#
# 54 & 23 = 110110 & 010111
#         = 010111
#         = 010110
#         = 22
# 0 ^ 22 = 000000 ^ 010110
#        = 010110
#        = 010110
#        = 22
#
# 15 | 6 = 1111 | 0110
#        = 1111
#        = 15
# 15 >> 1 = 1111 >> 1 = 0111 = 7 (15//2^1 = 15//2 =7)
# 7 % 5 = 2
#
# final expression = 25 * 14 - 22 + 2
#                  = 350 - 20
#                  = 330

# %%
(((128 >> 3) & (45 | 18)) ^ (7**2 % 10)) * ((36 // 5) << 1)-((91 % 7 * 2**3) ^ 
(54 & 23) ) + ((15 | 6) >> 1) % 5
# Out:
# 330

# %% [markdown]
# ##### Question - 10
#
# 17 ** 2 = 289
# 289 % 13 = 3
# 3 << 2 = 11 << 2 = 1100 = 12 (3 * 2^2 = 12)
#
# 64 >> 2 = 1000000 >> 2 = 0010000 = 16 (64 / 2^2 = 16)
# 9 & 5 = 1001 & 0101
#       = 0101
#       = 0001
#       = 1
# 16 | 1 = 10000 | 00001 = 10001 = 17
#
# 12 ^ 17 = 01100 ^ 10001
#         = 10001
#         = 11101
#         = 29
#
# 3 ** 2 = 9
# 45 % 7 = 3
# 3 * 9 = 27
# 27 // 6 = 4
#
# 28 | 12 = 11100 | 01100 = 11100 = 28
# 35 & 19 = 100011 & 010011
#         = 010011
#         = 000011
#         = 3
#
# 28 ^ 3 = 11100 ^ 00011
#        = 00011
#        = 11111
#        = 31
#
# 2 ** 5 = 32
# 7 % 3 = 1
# 32 + 1 = 33
#
# 81 // 9 = 9
# 9 << 1 = 1001 << 1 = 10010 = 18 (9 * 2^1 = 18)
# 18 % 5 = 3
# 3 == 3 (True)
#
# 56 >> 3 = 111000 >> 3 = 000111 = 7 (56/2^3 = 7)
# 15 | 4 = 1111 | 0100 = 1111 = 15
# 7 & 15 = 0111 & 1111
#        = 1111
#        = 0111
#        = 7
# 7 != 7 (False)
#
# 2 ** 3 = 8
# 99 % 8 = 3
# 3 * 8 = 24
# 24 // 5 = 4
#
# 42 & 27 = 101010 & 011011
#         = 011011
#         = 001010
#         = 10
# 10 > 25 (False)
#
# final expression = 29 > 4 and not 31 < 33 or (True and False) and not False
#                  = True and not True or False and not False
#                  = True and False or False and True
#                  = False or False
#                  = False

# %%
(((17**2 % 13) << 2) ^ ((64 >> 2) | (9 & 5))) > ((45 % 7 * 3**2) // 
6) and not (((28 | 12) ^ (35 & 19) ) < (2**5 + 7 % 3)) or ((((81 // 
9) << 1) % 5) == 3 and ((56 >> 3) & (15 | 4)) != 7) and not((99 % 8 * 2**3 // 
5) ^ (42 & 27) > 25)
# Out:
# False

# %% [markdown]
# >Note: Boxing and using \mathtt{} to get math text for coding style
# $$
# \boxed{
# \begin{align*}
# \text{Result} &= \mathtt{Block\,Left}\,\mathtt{and}\,\mathtt{not}\,\mathtt{Block\,Middle}\,\mathtt{or}\,\mathtt{Block\,Right} \\
#                &= 0 \;\mathtt{and} \;\mathtt{not} \; 1 \;\mathtt{or} \; 0 \\
#                &= 0 \;\mathtt{and} \; 0 \;\mathtt{or} \; 0 \\
#                &= 0 \;\mathtt{or} \; 0 \\
#                &= 0 \;\Rightarrow\; \text{False}
# \end{align*}
# }
# $$

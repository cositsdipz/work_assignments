# %% [markdown]
# ##### Assignment 1 - B
# ##### Python Basics: Bitwise, Arithmetic & Logical Expressions

# %% [markdown]
# <!-- $$
# \begin{array}{l|l}
# \text{Priority} & \text{Operators} \\
# \hline
# \text{Highest} & () \\
# & ** \\
# & +x, -x, \sim x \\
# \hline
# & *, /, //, \% \\
# & +, - \\
# \hline
# \text{Lowest} & \text{or} \\
# \end{array}
# $$ -->

# %% [markdown]
# $\small \underline{\textbf{Python Operator Precedence}} \quad \text{(\,Highest to Lowest\,)}$
# $$
# {\small
# \begin{array}{l|l}
# \text{Operators} & \text{Description} \\
# \hline
# () & \text{Parentheses} \\
# ** & \text{Exponentiation} \\
# +x, -x, \textasciitilde x & \text{Unary positive, negative, bitwise NOT} \\
# *, /, //, \% & \text{Multiply, Division, Floor Division, Modulo} \\
# +, - & \text{Addition, Subtraction} \\
# \ll, \gg & \text{Bitwise left shift, Bitwise right shift} \\
# \& & \text{Bitwise AND} \\
# \textasciicircum & \text{Bitwise XOR} \\
# \textbar & \text{Bitwise OR} \\
# <, <=, >, >=, !=, == & \text{Comparisons} \\
# not & \text{Logical NOT} \\
# and & \text{Logical AND} \\
# or & \text{Logical OR}
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \underline{\textbf{Bitwise Operations Quick Reference}}$
# $$
# {\small
# \begin{array}{l|l}
# \text{Operators} & \text{Description} \\
# \hline
# \& - AND & \text{both bits must be 1} \\
# \textbar - OR & \text{at least one bit is 1} \\
# \textasciicircum - XOR & \text{bits are different} \\
# \textasciitilde - NOT & \text{flip all bits} \\
# \ll - Left \ Shift & \text{multiply by $2^n$} \\
# \gg - Right \ Shift & \text{divide by $2^n$} \\
# \end{array}
# }
# $$

# %% [markdown]
# $\small \underline{\textbf{Some Common Conversions:}}$
# $7_{10} = 0111_{2}$
# $8_{10} = 1000_{2}$
# $14_{10} = 1110_{2}$
# $9_{10} = 1001_{2}$
# $15_{10} = 1111_{2}$
# $16_{10} = 10000_{2}$

# %% [markdown]
# $\small \underline{\textbf{Question - 1}} \quad \text{Evaluate the following expression:}$
# $ \small (7 \,\textasciicircum\, 3) * (8 \gg 2) + 9 \,\%\, 4 $

# %% [markdown]
# $$
# \small \text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $$

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{XOR ($\textasciicircum$)} & 7 & 3 &
# \begin{array}{c}
# 0111 \\
# 0011 \\ \hline
# 0100 \; \Rightarrow \; 4
# \end{array} \\
# \hline
# \text{B} & \text{Right \,Shift ($\gg$)} & 8 & 2 &
# \begin{array}{c}
# 1000 \gg 2 \\
# 0010 \; \Rightarrow \; 2
# \end{array} \\
# \hline
# \text{C} & \text{Modulo (\%)} & 9 & 4 &
# \begin{array}{c}
# 9 \,\div 4 = 2 \; \text{Remainder} \; 1 \\
# \hline
# 9 \,\%\, 4 \; \Rightarrow 1
# \end{array}\\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# <!--$$
# \boxed{\text{Result} = \text{Block A} \cdot \text{Block B} + \text{Block C}
#                   = 4 * 2 + 1
#                   = 9}
# $$-->
#
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} \cdot\, \text{Block B} + \text{Block C} \\
#                         & = \, 4 \cdot 2 + 1 \\
#                         & = \, 9
# \end{align*}
# }
# $$

# %%
# Verification of Question - 1
result = (7 ^ 3) * (8 >> 2) + 9 % 4
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 9
# Binary: 0b1001

# %% [markdown]
# $\small \underline{\textbf{Question - 2}} \quad\ \text{Evaluate the following expression:}$
# $\small (14 \gg 1) + (9 \,\%\, 5) * (6 \,\textasciicircum\, 2)$

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{Right \,Shift ($\gg$)} & 14 & 1 & \begin{array}{c}
# \small 14 \small \gg 1 \\
# \frac{14}{2^1} \,\Rightarrow 7
# \end{array} \\
# \hline
# \text{B} & \text{Modulo (\%)} & 9 & 5 &
# \begin{array}{c}
# 9 \,\%\, 5 \,\Rightarrow\, 4 \\
# \end{array} \\
# \hline
# \text{C} & \text{XOR ($\textasciicircum$)} & 6 & 2 &
# \begin{array}{c}
# 0110 \\
# 0010 \\ \hline
# 0100 \,\Rightarrow\, 4
# \end{array} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} + \,\text{Block B} \,\cdot\, \text{Block C} \\
#                         & = \, 7 + 4 \cdot 4 \\
#                         & = \, 23
# \end{align*}
# }
# $$

# %%
# Verification of Question - 2
result = (14 >> 1) + (9 % 5) * (6 ^ 2)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 23
# Binary: 0b10111

# %% [markdown]
# $\small \underline{\textbf{Question - 3:}} \quad
# \text{Evaluate the following expression:}
# $
# $\small (5**\;3 \;//\; 4 \;\%\; 7 \ll 2) + (18 \gg 2) * (9 \;\textasciicircum\; 6 \;\%\; 5)
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{Exponent \,(**)} & 5 & 3 &
# 5^3 \Rightarrow 125 \\
# \text{A} & \text{Floor Division \,(//)} & 125 & 4 &
# 125 // 4 \; \Rightarrow 31 \\
# \text{A} & \text{Modulo \,(\%)} & 31 & 7 &
# 31 \% 7 \; \Rightarrow 3 \\
# \text{A} & \text{Left \, Shift ($\ll$)} & 3 & 1 &
# \begin{array}{c}
# 0011 \ll 2 \\
# 1100 \; \Rightarrow \; 12
# \end{array} \\
# \hline
# \text{B} & \text{Right \,Shift ($\gg$)} & 18 & 2 &
# \begin{array}{c}
# 10010 \gg 2 \\
# 00100 \; \Rightarrow \; 4
# \end{array} \\
# \hline
# \text{C} & \text{Modulo \,(\%)} & 6 & 5 &
# 6 \,\%\, 5 \; \Rightarrow 1 \\
# \text{C} & \text{XOR \,($\textasciicircum$)} & 9 & 1 &
# \begin{array}{c}
# 01001 \\
# 00001 \\ \hline
# 01000 \, \Rightarrow 8
# \end{array}\\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} + \text{Block B} \cdot \text{Block C}\\
#                 & = \, 12 + 4 \cdot 8 \\
#                 & = \, 44
# \end{align*}
# }
# $$

# %%
# Verification of Question - 3
result = (5**3 // 4 % 7 << 2) + (18 >> 2) * (9 ^ 6 % 5)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 44
# Binary: 0b101100

# %% [markdown]
# $\small \underline{\textbf{Question - 4:}} \quad
# \text{Evaluate the following expression:}
# $
# $\small (27 \;\%\; 5 * 3**\,2 //\, 4) \;\textasciicircum\; (48 \,\gg\, 3) + (14 \;\&\; 9 \,\ll\, 1)
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{Exponent \,(**)} & 3 & 2 &
# 3^2 \; \Rightarrow 9 \\
# \text{A} & \text{Modulo \,(\%)} & 27 & 5 &
# 27 \,\%\, 5 \; \Rightarrow 2 \\
# \text{A} & \text{Multiple \,(*)} & 9 & 2 &
# 9 \,\cdot\, 2 \; \Rightarrow 18 \\
# \text{A} & \text{Floor Division \,(//)} & 18 & 4 & 18 // 4 \; \Rightarrow 4 \\
# \hline
# \text{B} & \text{Right Shift \,($\gg$)} & 48 & 3 &
# \begin{array}{c}
# 48 \gg 3 \\
# \frac{48}{2^3}\; \Rightarrow 6
# \end{array} \\
# \hline
# \text{C} & \text{Left Shift \,($\ll$)} & 9 & 1 &
# \begin{array}{c}
# 9 \ll 1 \\
# 9 \cdot 2^1 \; \Rightarrow 18
# \end{array} \\
# \text{C} & \text{And (\&)} & 14 & 18 &
# \begin{array}{c}
# 01110 \\
# 10010 \\ \hline
# 00010 \; \Rightarrow 2
# \end{array}\\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} \,\textasciicircum\, \text{Block B} + \text{Block C}\\
#                 & = \, 4 \,\textasciicircum\, 6 + 2 \\
#                 & = \, 4 \,\textasciicircum\, 8 \\
#                 & = 0100 \,\textasciicircum\, 1000 \\
#                 & = 1100 \Rightarrow 12
# \end{align*}
# }
# $$

# %%
# Verification of Question - 4
result = (27 % 5 * 3**2 // 4) ^ (48 >> 3) + (14 & 9 << 1)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 12
# Binary: 0b1100

# %% [markdown]
# $\small \underline{\textbf{Question - 5:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{OR \,(\,$\textbar$\,)} & 19 & 6 & \begin{array}{c}
# 10011 \\
# 00110 \\ \hline
# 10111 \; \Rightarrow \; 23
# \end{array} \\
# \text{A} & \text{AND (\&)} & 28 & 14 & \begin{array}{c}
# 11100 \\
# 01110 \\ \hline
# 01100 \; \Rightarrow\; 12
# \end{array} \\
# \text{A} & \text{XOR (\,$\textasciicircum$\,)} & 23 & 12 & \begin{array}{c}
# 10111 \\
# 01100 \\ \hline
# 11011 \;\Rightarrow\; 27
# \end{array} \\
# \hline
# \text{B} & \text{Left Shift \,($\ll$)} & 3 & 2 & \begin{array}{c}
# 3 \ll 2 \\
# 3 \,\cdot\, 2^2 \; \Rightarrow 12
# \end{array} \\
# \hline
# \text{C} & \text{Exponent (**)} & 5 & 2 & 5^2 \;\Rightarrow\; 25 \\
# \text{C} & \text{Floor Division \,(//)} & 25 & 3 & 25 // 3 \; \Rightarrow \; 8 \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} \cdot \text{Block B} \;\%\; \text{Block C}\\
#                 & = \, 27 \cdot 12 \,\%\, 8 \\
#                 & = \, 324 \,\%\, 8 \\
#                 & = \, 4
# \end{align*}
# }
# $$

# %%
# Verification of Question - 5
result = ((19 | 6) ^ (28 & 14)) * (
3 << 2) % (5**2 // 3)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 4
# Binary: 0b100

# %% [markdown]
# $\small \underline{\textbf{Question - 6:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \text{A} & \text{AND \,(\&)} & 45 & 27 & \begin{array}{c}
# 101101 \\
# 011011 \\ \hline
# 001001 \; \Rightarrow \; 9
# \end{array} \\
# \text{A} & \text{Left Shift \,($\ll$)} & 9 & 2 & \begin{array}{c}
# 9 \,\ll\, 2 \\
# 9 \,\cdot\, 2^2 \;\Rightarrow\; 36
# \end{array} \\
# \hline
# \text{B} & \text{Exponent \,(**)} & 2 & 3 & 2^3 \;\Rightarrow\; 8 \\
# \text{B} & \text{Modulo \,(\%)} & 9 & 4 & 9 \,\%\, 4 \;\Rightarrow\; 1 \\
# \text{B} & \text{Addition \,(+)} & 1 & 8 & 1 + 8 \; \Rightarrow\; 9 \\
# \hline
# \text{C} & \text{Left Shift \,($\ll$)} & 5 & 1 & \begin{array}{c}
# 5 \,\ll\, 1 \\
# 5 \,\cdot\, 2^1 \; \Rightarrow\; 10
# \end{array} \\
# \text{C} & \text{XOR\,($\textasciicircum$)} & 16 & 10 & \begin{array}{c}
# 10000 \\
# 01010 \\ \hline
# 11010 \;\Rightarrow\; 26
# \end{array} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A} \,//\,  \text{Block B} \,+\, \text{Block C}\\
#                 & = \, 36 \,//\, 9 \,+\, 26 \\
#                 & = \, 4 \,+\, 26 \\
#                 & = \, 30
# \end{align*}
# }
# $$

# %%
# Verification of Question - 6
result = ((45 & 27) << 2) // (9%4 + (2**3)) + (16 ^ (5 << 1))
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 30
# Binary: 0b11110

# %% [markdown]
# $\small \underline{\textbf{Question - 7:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A}  \text{Block B} \text{Block C}\\
#                 & = \,  \\
#                 & = \,
# \end{align*}
# }
# $$

# %%
# Verification of Question - 7
result = ((15**2 % 7 + 48>>2) ^ (
19 & 13|6)) * (7<<3 // 5) + (
(42%5 * 3**3 // 4) > (18>>1)) and not (
(9|4) ^ (12&7) 
< (3**2 + 5)) or (27//4 % 3==2)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: False
# Binary: 0b0

# %% [markdown]
# $\small \underline{\textbf{Question - 8:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A}  \text{Block B} \text{Block C}\\
#                 & = \,  \\
#                 & = \,
# \end{align*}
# }
# $$

# %%
# Verification of Question - 8
result = ((63&45) << 1 | (72>>3)) ^ (
(11%3 * 2**4) // (6+1)) + (((8|3) 
^ 5) * (16>>2) % 7) - ((25%6) << 2)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 91
# Binary: 0b1011011

# %% [markdown]
# $\small \underline{\textbf{Question - 9:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A}  \text{Block B} \text{Block C}\\
#                 & = \,  \\
#                 & = \,
# \end{align*}
# }
# $$

# %%
# Verification of Question - 9
result = (((128>>3) & (45|18)) ^ (7**2 % 10)
)*((36//5) << 1)-((91%7 * 2**3) ^ 
(54&23)) + ((15|6)>>1) % 5
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: 330
# Binary: 0b101001010

# %% [markdown]
# $\small \underline{\textbf{Question - 10:}} \quad
# \text{Evaluate the following expression:}
# $
# $
# $

# %% [markdown]
# $
# \small \text{Step - 1:}\quad\text{Breaking down the expression into blocks and operating on these individual blocks in tabular form}
# $
# $
# $

# %% [markdown]
# $$
# {\small
# \begin{array}{clccc}
# \hline
# \text{Block} & \text{Operation} & \text{Decimal A} & \text{Decimal B} & \text{Result} \\
# \hline
# \end{array}
# }
# $$

# %% [markdown]
# $ \small \text{Step - 2:}\quad\text{Calculating the final expression}
# $

# %% [markdown]
# $$
# \boxed{
# \begin{align*}
# \text{Result} & = \, \text{Block A}  \text{Block B} \text{Block C}\\
#                 & = \,  \\
#                 & = \,
# \end{align*}
# }
# $$

# %%
# Verification of Question - 10
result = (((17**2 % 13)<<2) ^ ((64>>2) | (
9&5))) > ((45%7 * 3**2) // 6) and not ((
(28|12) ^ (35&19)) < (2**5 + 7%3)) or (((
(81//9)<<1) % 5) == 3 and ((56>>3) & (15|4)) 
!= 7) and not((99%8 * 2**3 // 5)^(42&27)>25)
print(f'Result: {result}')
print(f'Binary: {bin(result)}')
# Out:
# Result: False
# Binary: 0b0
